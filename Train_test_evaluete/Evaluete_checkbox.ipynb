# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !pip freeze --local > /content/gdrive/My\ Drive/colab_installed.txt

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# !cd keras-retinanet && pip install . --user
# %cd keras-retinanet/
# !pip inst\
# all .
# !pip install keras==2.3.1
# #!pip install --upgrade keras

# %%
# !cd /content/gdrive/My Drive/keras-retinanet && pip install. --user
# %cd /content/gdrive/My\ Drive/keras-retinanet
# !pip inst\
all .
#!pip install --upgrade keras
# !pip install keras==2.3.1

# %%
# !pip install gdown
# !pip install tensorflow-gpu
# !pip install tensorflow==2.2.0
import tensorflow
print(tensorflow.__version__)

# %%
# !python setup.py build_ext --inplace

# %% [markdown]
# [link text](https://) ratios  = np.array([0.01,0.03,0.09,0.27, 1], keras.backend.floatx()),
#
#
#   scales  = np.array([2 ** 0, 2 ** (1.0 / 3.0), 2 ** (2.0 / 3.0),3.5], keras.backend.floatx()
#
#
#
# file:///C:/Users/User/Downloads/Deep_RetinaNet-Based_Detection_and_Classification_.pdf

# %%
# !python /content/gdrive/My\ Drive/keras-retinanet/keras_retinanet/bin/convert_model.py  /content/gdrive/My\ Drive/RETINANET_files/Snapshot_weight_folder/resnet50_csv_1701885.h5  /content/gdrive/My\ Drive/RETINANET_files/resnet50_csv_1701885.h5

# %%
# !python /content/gdrive/My\ Drive/keras-retinanet/keras_retinanet/bin/evaluate.py --score-threshold 0.5   --save-path /content/gdrive/My\ Drive/RETINANET_files/resnet50_csv_1701885.h5  csv /content/gdrive/My\ Drive/RETINANET_files/Test_data_Retinanet.csv  /content/gdrive/My\ Drive/RETINANET_files/classess.csv /content/gdrive/My\ Drive/RETINANET_files/resnet50_csv_1701885.h5

# %%
#!python /content/gdrive/My\ Drive/keras-retinanet/keras_retinanet/bin/convert_model.py --help

# %%
#!python /content/gdrive/My\ Drive/keras-retinanet/keras_retinanet/bin/evaluate.py --help
